# %%
'''
Musical Track Database
This application will read an iTunes export file in CSV format and produce a properly normalized database with this structure:

CREATE TABLE Artist (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name    TEXT UNIQUE
);

CREATE TABLE Genre (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name    TEXT UNIQUE
);

CREATE TABLE Album (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    artist_id  INTEGER,
    title   TEXT UNIQUE
);

CREATE TABLE Track (
    id  INTEGER NOT NULL PRIMARY KEY 
        AUTOINCREMENT UNIQUE,
    title TEXT  UNIQUE,
    album_id  INTEGER,
    genre_id  INTEGER,
    len INTEGER, rating INTEGER, count INTEGER
);

If you run the program multiple times in testing or with different files, make sure to empty out the data before each run.

You can use this code as a starting point for your application: http://www.py4e.com/code3/tracks.zip. The ZIP file contains the tracks.csv file to be used for 
this assignment. You can export your own tracks from iTunes and create a database, but for the database that you turn in for this assignment, only use the 
tracks.csv data that is provided. You can adapt the tracks_csv.py application in the zip file to complete the assignment.

To grade this assignment, the program will run a query like this on your uploaded database and look for the data it expects to see:

SELECT Track.title, Artist.name, Album.title, Genre.name 
    FROM Track JOIN Genre JOIN Album JOIN Artist 
    ON Track.genre_id = Genre.ID and Track.album_id = Album.id 
        AND Album.artist_id = Artist.id
    ORDER BY Artist.name LIMIT 3

The expected result of the modified query on your database is: (shown here as a simple HTML table with titles)

Track                                       Artist          Album               Genre
Chase the Ace	                            AC/DC	        Who Made Who	    Rock
D.T.	                                    AC/DC	        Who Made Who	    Rock
For Those About To Rock (We Salute You)	    AC/DC	        Who Made Who	    Rock
'''
import sqlite3

trackdb = sqlite3.connect('trackdb.sqlite')
cursor = trackdb.cursor()

cursor.executescript('''
DROP TABLE IF EXISTS Artist;
DROP TABLE IF EXISTS Genre;
DROP TABLE IF EXISTS Album;
DROP TABLE IF EXISTS Track;

CREATE TABLE Artist (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name    TEXT UNIQUE
);

CREATE TABLE Genre(
    id INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    name TEXT UNIQUE
);

CREATE TABLE Album (
    id  INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT UNIQUE,
    artist_id  INTEGER,
    title   TEXT UNIQUE
);

CREATE TABLE Track (
    id  INTEGER NOT NULL PRIMARY KEY 
        AUTOINCREMENT UNIQUE,
    title TEXT  UNIQUE,
    album_id  INTEGER,
    genre_id INTEGER,
    len INTEGER, rating INTEGER, count INTEGER
);
''')

handle = open('tracks.csv')

for line in handle:
    line = line.strip();
    pieces = line.split(',')
    if len(pieces) < 7 : continue

    name = pieces[0]
    artist = pieces[1]
    genre = pieces[2]
    album = pieces[3]
    count = pieces[4]
    rating = pieces[5]
    length = pieces[6]

    print(name, artist, album, genre, count, rating, length)

    cursor.execute('''INSERT OR IGNORE INTO Artist (name) 
        VALUES ( ? )''', ( artist, ) )
    cursor.execute('SELECT id FROM Artist WHERE name = ? ', (artist, ))
    artist_id = cursor.fetchone()[0]

    cursor.execute('''INSERT OR IGNORE INTO Genre (name) 
        VALUES ( ? )''', ( genre, ) )
    cursor.execute('SELECT id FROM Genre WHERE name = ? ', (genre, ))
    genre_id = cursor.fetchone()[0]

    cursor.execute('''INSERT OR IGNORE INTO Album (title, artist_id) 
        VALUES ( ?, ? )''', ( album, artist_id ) )
    cursor.execute('SELECT id FROM Album WHERE title = ? ', (album, ))
    album_id = cursor.fetchone()[0]

    cursor.execute('''INSERT OR REPLACE INTO Track
        (title, album_id, genre_id, len, rating, count) 
        VALUES ( ?, ?, ?, ?, ?, ? )''', 
        ( name, album_id, genre_id, length, rating, count ) )

    trackdb.commit()
# Out:
# Another One Bites The Dust Queen 55 Greatest Hits 100 217103 Rock
# Asche Zu Asche Rammstein 79 Herzeleid 100 231810 Industrial
# Beauty School Dropout Various 48 Grease 100 239960 Soundtrack
# Black Dog Led Zeppelin 109 IV 100 296620 Rock
# Bring The Boys Back Home Pink Floyd 33 The Wall [Disc 2] 100 87118 Rock
# Circles Bryan Lee 54 Blues Is 60 355369 Funk
# Comfortably Numb Pink Floyd 36 The Wall [Disc 2] 100 384130 Rock
# Crazy Little Thing Called Love Queen 38 Greatest Hits 100 163631 Rock
# Electric Funeral Black Sabbath 44 Paranoid 100 293015 Metal
# Fat Bottomed Girls Queen 38 Greatest Hits 100 257515 Rock
# For Those About To Rock (We Salute You) AC/DC 84 Who Made Who 100 353750 Rock
# Four Sticks Led Zeppelin 84 IV 100 284421 Rock
# Furious Angels Rob Dougan 54 The Matrix Reloaded 100 330004 Soundtrack
# Gelle Bryan Lee 45 Blues Is 60 199836 Blues/R&B
# Going To California Led Zeppelin 100 IV 100 215666 Rock
# Gotta Move Fast Michael Loceff 19 0 100 287529 0
# Grease Various 42 Grease 100 205792 Soundtrack
# Hand of Doom Black Sabbath 36 Paranoid 100 429609 Metal
# Got my Mojo Working The Canettes Blues Band 52 On Tap & In the Can 100 310517 Blues/R&B
# Sweet Home Chicago The Canettes Blues Band 27 On Tap & In the Can 100 375849 Blues/R&B
# Heavy Love The Canettes Blues Band 28 On Tap & In the Can 100 253544 Blues/R&B
# Cold Cold Feeling The Canettes Blues Band 43 On Tap & In the Can 100 261929 Blues/R&B
# Lonely Avenue The Canettes Blues Band 24 On Tap & In the Can 100 292022 Blues/R&B
# Good Morning Little Schoolgirl The Canettes Blues Band 20 On Tap & In the Can 100 278648 Blues/R&B
# Dust My Broom The Canettes Blues Band 24 On Tap & In the Can 100 299311 Blues/R&B
# Gimme' Some Lovin The Canettes Blues Band 35 On Tap & In the Can 100 227239 Blues/R&B
# Everybody Needs Somebody to Love The Canettes Blues Band 24 On Tap & In the Can 100 195186 Blues/R&B
# Black Magic Woman The Canettes Blues Band 31 On Tap & In the Can 100 442644 Blues/R&B
# Steppin' Rooster The Canettes Blues Band 21 On Tap & In the Can 100 704862 Blues/R&B
# Our Love is Drifting The Canettes Blues Band 15 On Tap & In the Can 100 292649 Blues/R&B
# Doin' 100 The Canettes Blues Band 20 On Tap & In the Can 100 343980 Blues/R&B
# Track 01 Sinister Symphony 7 0 100 259944 0
# Track 02 Sinister Symphony 14 0 100 230948 0
# Track 03 Sinister Symphony 16 0 100 206497 0
# Track 04 Sinister Symphony 12 0 100 188891 0
# Track 05 Sinister Symphony 12 0 100 258664 0
# Track 06 Sinister Symphony 9 0 100 186383 0
# Track 07 Sinister Symphony 11 0 100 164440 0
# Track 08 Sinister Symphony 4 0 0 311771 0
# Mother Joy Matt Ender 463 Natural Wonders Music Sampler 1999 0 287294 New Age
# Soldier's Lament Steve McDonald 371 Natural Wonders Music Sampler 1999 0 347193 New Age
# Dulaman Altan 403 Natural Wonders Music Sampler 1999 0 223007 New Age
# The Arrow Chris Spheeris 416 Natural Wonders Music Sampler 1999 0 319869 New Age
# Spanish Eyes La Esperanza 375 Natural Wonders Music Sampler 1999 0 259030 New Age
# Banana Bay Luis Villegas 403 Natural Wonders Music Sampler 1999 0 198060 New Age
# Aguas De Marco Rosa Passos 407 Natural Wonders Music Sampler 1999 0 179408 New Age
# Tamborea Energipsy 355 Natural Wonders Music Sampler 1999 0 235389 New Age
# Gone Hollie Smith 362 Natural Wonders Music Sampler 1999 0 196414 New Age
# The Immigrant Joanie Madden 350 Natural Wonders Music Sampler 1999 0 362631 New Age
# Pahrump-Big Water Cusco 342 Natural Wonders Music Sampler 1999 0 191634 New Age
# Seeker's Quest Cheryl Gunn 337 Natural Wonders Music Sampler 1999 0 236434 New Age
# Floating To Forever Dean Everson 337 Natural Wonders Music Sampler 1999 0 351686 New Age
# Open Road Jeff Bailey 10 Relaxing Jazz 0 318563 Jazz
# eniment-version-a 0 28 0 0 32032 0
# ruby_on_rails 0 0 0 0 1207920 0
# AcceleratorBlues The Canettes Blues Band 71 0 0 336457 0
# HenryFordBlues The Canettes Blues Band 4 0 0 298344 0
# Mistletoe And Holly Frank Sinatra 257 Seasons Greatings 0 138501 Holiday
# O Holy Night Bing Crosby 150 Seasons Greatings 0 214021 Holiday
# Have Yourself A Merry Little Christmas Frank Sinatra 252 Seasons Greatings 0 208248 Holiday
# Do You Hear What I Hear Bing Crosby 155 Seasons Greatings 0 164728 Holiday
# I'll Be Home For Christmas Frank Sinatra 249 Seasons Greatings 0 190876 Holiday
# Track 01 Kaiser Chiefs 2 0 0 205008 0
# Track 02 Kaiser Chiefs 1 0 0 288313 0
# Track 03 Kaiser Chiefs 3 0 0 237061 0
# Track 04 Kaiser Chiefs 3 0 0 199575 0
# Track 05 Kaiser Chiefs 1 0 0 197799 0
# Track 06 Kaiser Chiefs 2 0 0 157753 0
# Track 07 Kaiser Chiefs 3 0 0 204199 0
# Track 08 Kaiser Chiefs 1 0 0 246595 0
# Track 09 Kaiser Chiefs 1 0 0 164754 0
# Track 10 Kaiser Chiefs 0 0 0 325955 0
# Track 11 Kaiser Chiefs 2 0 0 222511 0
# Track 12 Kaiser Chiefs 1 0 0 237426 0
# Track 13 Kaiser Chiefs 1 0 0 279066 0
# Track 14 Kaiser Chiefs 3 0 0 218566 0
# Track 15 Kaiser Chiefs 1 0 0 147226 0
# Voices Disturbed 0 The Sickness 0 191764 Alternative
# The Game Disturbed 1 The Sickness 0 227134 Alternative
# Stupify Disturbed 1 The Sickness 0 274233 Alternative
# Down With The Sickness Disturbed 1 The Sickness 0 278726 Alternative
# Violence Fetish Disturbed 0 The Sickness 0 203833 Alternative
# Fear Disturbed 4 The Sickness 0 227004 Alternative
# Numb Disturbed 0 The Sickness 0 224940 Alternative
# Want Disturbed 0 The Sickness 0 232803 Alternative
# Conflict Disturbed 5 The Sickness 0 275330 Alternative
# Shout 2000 Disturbed 1 The Sickness 0 257802 Alternative
# Droppin' Plates Disturbed 4 The Sickness 0 229302 Alternative
# Meaning Of Life Disturbed 3 The Sickness 0 242599 Alternative
# edu2020 0 0 0 0 805680 0
# PY4INF-01-Intro.mp3 Recording by Dr. Chuck 1 Python for Informatics's official Podcast. 0 3428075 Podcast
# ted_03 0 1 0 0 745700 0
# Pomp and Circumstance Marches No. 1 Edward Elgar 0 0 0 113214 0
# Eben Upton: Raspberry Pi IEEE Computer Society 2 Computing Conversations 0 661368 Podcast
# Andrew Tanenbaum: Writing the Book on Networks IEEE Computer Society 4 Computing Conversations 0 535040 Podcast
# Massimo Banzi: Building Arduino IEEE Computer Society 1 Computing Conversations 0 567745 Podcast
# PY4INF-04-Functions.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 1683800 Podcast
# PY4INF-02-Expressions.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 2578416 Podcast
# PY4INF-03-Conditional.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 2296058 Podcast
# PY4INF-05-Iterations.mp3 Recording by Dr. Chuck 1 Python for Informatics's official Podcast. 0 2804297 Podcast
# PY4INF-06-Strings.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 1677844 Podcast
# PY4INF-07-Files.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 1478713 Podcast
# PY4INF-08-Lists.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 1636231 Podcast
# PY4INF-09-Dictionaries.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 2254445 Podcast
# PY4INF-10-Tuples.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 1597596 Podcast
# PY4INF-11-Regex.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 2123702 Podcast
# John C. Hollar: History of Computing IEEE Computer Society 1 Computing Conversations 0 694073 Podcast
# Bob Metcalfe: Ethernet at Forty IEEE Computer Society 0 Computing Conversations 0 1031392 Podcast
# Gordon Bell: Building Blocks of Computing IEEE Computer Society 1 Computing Conversations 0 744620 Podcast
# Ian Horrocks: Standardizing OWL IEEE Computer Society 1 Computing Conversations 0 572212 Podcast
# Katie Hafner: The Origins of the Internet IEEE Computer Society 1 Computing Conversations 0 652460 Podcast
# Larry Smarr: Building Mosaic IEEE Computer Society 0 Computing Conversations 0 894693 Podcast
# Len Kleinrock: The Theory of Packets IEEE Computer Society 1 Computing Conversations 0 674742 Podcast
# Mitchell Baker: The Mozilla Foundation IEEE Computer Society 0 Computing Conversations 0 994246 Podcast
# Pooja Sankar: Building the Piazza Collaboration System IEEE Computer Society 0 Computing Conversations 0 496404 Podcast
# Van Jacobson: Content-Centric Networking IEEE Computer Society 0 Computing Conversations 0 780251 Podcast
# The Apache Software Foundation IEEE Computer Society 0 Computing Conversations 0 542484 Podcast
# A Brief History of Packets IEEE Computer Society 0 Computing Conversations 0 1004643 Podcast
# Discovering JavaScript Object Notation IEEE Computer Society 0 Computing Conversations 0 650971 Podcast
# Inventing PHP IEEE Computer Society 0 Computing Conversations 0 494915 Podcast
# Monash Museum of Computing History IEEE Computer Society 0 Computing Conversations 0 362657 Podcast
# The Rise of JavaScript IEEE Computer Society 0 Computing Conversations 0 526132 Podcast
# lo_and_behold_audio 0 0 0 0 33116 0
# 1996-02-tci07 0 0 0 0 3600096 0
# Joseph Hardin: NCSA Mosaic IEEE Computer Society 0 Computing Conversations 0 845635 Podcast
# Len Kleinrock on the Internet's First Two Packets IEEE Computer Society 1 Computing Conversations 0 594390 Podcast
# Pomp and Circumstance Marches No. 1 Edward Elgar 1 0 0 113214 0
# Doug Van Houweling on Building the NSFNet IEEE Computer Society 0 Computing Conversations 0 773146 Podcast
# Computing Conversations: Nathaniel Borenstein on MIME IEEE Computer Society 0 Computing Conversations 0 682135 Podcast
# You Don't Mess Around With Jim Jim Croce 0 Classic Hits 0 184398 Folk
# Andrew S. Tanenbaum on MINIX IEEE Computer Society 0 Computing Conversations 0 603000 Podcast
# Computing Conversations: Elizabeth Fong on SQL Standards IEEE Computer Society 0 Computing Conversations 0 533577 Podcast
# Nii Quaynor on Bringing the Internet to Africa IEEE Computer Society 1 Computing Conversations 0 673332 Podcast
# PHP-09-Transactions.mp3 Created by Sakai 0 SI 664 W14's official Podcast. 0 1728888 Podcast
# PHP-01-Intro.mp3 Created by Sakai 0 SI 664 W14's official Podcast. 0 2250624 Podcast
# PHP-02-Install.mp3 Created by Sakai 1 SI 664 W14's official Podcast. 0 0 Podcast
# PHP-04-Expressions.mp3 Created by Sakai 0 SI 664 W14's official Podcast. 0 2168064 Podcast
# PHP-05-Functions.mp3 Created by Sakai 0 SI 664 W14's official Podcast. 0 1446792 Podcast
# PHP-06-Strings.mp3 Created by Sakai 0 SI 664 W14's official Podcast. 0 417696 Podcast
# PHP-12-Sessions.mp3 Created by Sakai 0 SI 664 W14's official Podcast. 0 3624312 Podcast
# PHP-06-Objects.mp3 Created by Sakai 0 SI 664 W14's official Podcast. 0 2455368 Podcast
# SI664-13-JSON-A.mp3 Created by Sakai 0 SI 664 W14's official Podcast. 0 4407672 Podcast
# PHP-13-JavaScript.mp3 Created by Sakai 0 SI 664 W14's official Podcast. 0 3650088 Podcast
# PHP-09-Database-Design.mp3 Created by Sakai 0 SI 664 W14's official Podcast. 0 3591072 Podcast
# PHP-Tsugi-Install.mp3 Created by Sakai 0 SI 664 W14's official Podcast. 0 3181656 Podcast
# PHP-10-MySQL-PDO.mp3 Created by Sakai 0 SI 664 W14's official Podcast. 0 4536685 Podcast
# PHP-08-MySQL.mp3 Created by Sakai 0 SI 664 W14's official Podcast. 0 3994656 Podcast
# SI664-13-JSON-B.mp3 Created by Sakai 0 SI 664 W14's official Podcast. 0 1484616 Podcast
# IMS-Learning-Tools-Interoperability.mp3 Created by Sakai 0 SI 664 W14's official Podcast. 0 2185848 Podcast
# An Interview with Don Waters Matt Pasiewicz 2 CNI Event Coverage 0 1411082 Speech
# Pooja-Interview-Audio 0 0 0 0 1209129 0
# PY4INF-11-Regex.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 2123702 Podcast
# PY4INF-10-Tuples.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 1597596 Podcast
# PY4INF-09-Dictionaries.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 2254445 Podcast
# PY4INF-08-Lists.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 1636231 Podcast
# PY4INF-07-Files.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 1478713 Podcast
# PY4INF-06-Strings.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 1677844 Podcast
# PY4INF-05-Iterations.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 2804297 Podcast
# PY4INF-04-Functions.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 1683800 Podcast
# PY4INF-03-Conditional.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 2296058 Podcast
# PY4INF-02-Expressions.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 2578416 Podcast
# PY4INF-01-Intro.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 3428075 Podcast
# Py4Inf-11-Regex.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 2123702 Podcast
# Py4Inf-10-Tuples.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 1597596 Podcast
# Py4Inf-09-Dictionaries.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 2254445 Podcast
# Py4Inf-08-Lists.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 1636231 Podcast
# Py4Inf-07-Files.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 1478713 Podcast
# Py4Inf-06-Strings.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 1677844 Podcast
# Py4Inf-05-Iterations.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 2804297 Podcast
# Py4Inf-04-Functions.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 1683800 Podcast
# Py4Inf-03-Conditional.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 2296058 Podcast
# Py4Inf-02-Expressions.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 2578416 Podcast
# Py4Inf-01-Intro.mp3 Recording by Dr. Chuck 0 Python for Informatics's official Podcast. 0 3428075 Podcast
# Python 1994 Workshop 2-HD (1080p) 0 0 0 0 40033 0
# Python 1994 Workshop 2-HD (1080p) 0 0 0 0 40033 0
# Ian Foster on the Globus Project IEEE Computer Society 1 Computing Conversations 0 538305 Podcast
# Khan Academy and Computer Science IEEE Computer Society 1 Computing Conversations 0 558837 Podcast
# Guido van Rossumon the Early Years of Python IEEE Computer Society 1 Computing Conversations 0 701884 Podcast
# Guido van Rossum on the Modern Era of Python IEEE Computer Society 0 Computing Conversations 0 741616 Podcast
# John Resig on Building jQuery IEEE Computer Society 0 Computing Conversations 0 595983 Podcast
# Roy T. Fielding on Understanding the REST Style IEEE Computer Society 1 Computing Conversations 0 683650 Podcast
# 01-packets 0 0 0 0 770538 0
# 02-architecture 0 0 0 0 995289 0
# 03-link-layer 0 0 0 0 662617 0
# 04-internet-layer 0 0 0 0 1540688 0
# 05-dns 0 0 0 0 276532 0
# 06-transport-layer 0 0 0 0 652004 0
# 07-application-layer 0 0 0 0 1168282 0
# 08-secure-transport 0 0 0 0 754382 0
# 09-OSI 0 0 0 0 478074 0
# 10-wrap-up 0 0 0 0 258967 0
# 2015-08-Jain-01 0 1 0 0 714463 0
# 2015-08-Jain-01 0 0 0 0 714463 0
# Anil Jain: 25 Years of Biometric Recognition IEEE Computer Society 0 Computing Conversations 0 661368 Podcast
# Sleep Like a Baby Tonight U2 0 Songs of Innocence 0 301641 Rock
# Evergreen The Black Crowes 0 Warpaint 0 261373 Rock
# Oh Josephine The Black Crowes 0 Warpaint 0 398907 Rock
# Movin' On Down the Line The Black Crowes 0 Warpaint 0 342693 Rock
# Wounded Bird The Black Crowes 0 Warpaint 0 263453 Rock
# Volcano U2 0 Songs of Innocence 0 194116 Rock
# Wee Who See the Deep The Black Crowes 0 Warpaint 0 290520 Rock
# Cedarwood Road U2 0 Songs of Innocence 0 265268 Rock
# Locust Street The Black Crowes 0 Warpaint 0 255240 Rock
# Raised By Wolves U2 0 Songs of Innocence 0 245599 Rock
# The Troubles U2 0 Songs of Innocence 0 285843 Rock
# This Is Where You Can Reach Me Now U2 0 Songs of Innocence 0 305134 Rock
# God's Got It The Black Crowes 0 Warpaint 0 202653 Rock
# California (There Is No End to Love) U2 0 Songs of Innocence 0 239846 Rock
# Every Breaking Wave U2 0 Songs of Innocence 0 252162 Rock
# Song for Someone U2 0 Songs of Innocence 0 226763 Rock
# The Miracle (Of Joey Ramone) U2 0 Songs of Innocence 0 255382 Rock
# Iris (Hold Me Close) U2 0 Songs of Innocence 0 319457 Rock
# Goodbye Daughters of the Revolution The Black Crowes 0 Warpaint 0 304147 Rock
# Walk Believer Walk The Black Crowes 0 Warpaint 0 280253 Rock
# Microchip Jason Farnham 0 YouTube Audio Library 0 114336 Dance & Electronic
