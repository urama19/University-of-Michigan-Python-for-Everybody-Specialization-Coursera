# %%
import urllib.request, urllib.parse, urllib.error
import http
import sqlite3
import json
import time
import ssl
import sys

# https://py4e-data.dr-chuck.net/opengeo?q=Ann+Arbor%2C+MI
serviceurl = 'https://py4e-data.dr-chuck.net/opengeo?'

# Additional detail for urllib
# http.client.HTTPConnection.debuglevel = 1

conn = sqlite3.connect('opengeo.sqlite')
cur = conn.cursor()

cur.execute('''
CREATE TABLE IF NOT EXISTS Locations (address TEXT, geodata TEXT)''')

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

fh = open("where.data")
count = 0
nofound = 0
for line in fh:
    if count > 100 :
        print('Retrieved 100 locations, restart to retrieve more')
        break

    address = line.strip()
    print('')
    cur.execute("SELECT geodata FROM Locations WHERE address= ?",
        (memoryview(address.encode()), ))

    try:
        data = cur.fetchone()[0]
        print("Found in database", address)
        continue
    except:
        pass

    parms = dict()
    parms['q'] = address

    url = serviceurl + urllib.parse.urlencode(parms)

    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters', data[:20].replace('\n', ' '))
    count = count + 1

    try:
        js = json.loads(data)
    except:
        print(data)  # We print in case unicode causes an error
        continue

    if not js or 'features' not in js:
        print('==== Download error ===')
        print(data)
        break

    if len(js['features']) == 0:
        print('==== Object not found ====')
        nofound = nofound + 1

    cur.execute('''INSERT INTO Locations (address, geodata)
        VALUES ( ?, ? )''',
        (memoryview(address.encode()), memoryview(data.encode()) ) )

    conn.commit()

    if count % 10 == 0 :
        print('Pausing for a bit...')
        time.sleep(5)

if nofound > 0:
    print('Number of features for which the location could not be found:', nofound)

print("Run geodump.py to read the data from the database so you can vizualize it on a map.")
# Out:
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=AGH+University+of+Science+and+Technology
# Retrieved 1559 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Academy+of+Fine+Arts+Warsaw+Poland
# Retrieved 1693 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=American+University+in+Cairo
# Retrieved 1545 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Arizona+State+University
# Retrieved 1562 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Athens+Information+Technology
# Retrieved 1424 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=BITS+Pilani
# Retrieved 1285 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Babcock+University
# Retrieved 1412 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Banaras+Hindu+University
# Retrieved 1603 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Bangalore+University
# Retrieved 1581 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Baylor+University
# Retrieved 1509 characters {"type":"FeatureColl
# Pausing for a bit...
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Beijing+normal+university
# Retrieved 1465 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Belarusian+State+University
# Retrieved 1295 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Belgrade+University
# Retrieved 1168 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Beloit+College
# Retrieved 1414 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Belorussian+State+University
# Retrieved 1146 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Ben+Gurion+University
# Retrieved 1501 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Boston+University
# Retrieved 1498 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=California+Polytechnic+State+University+of+San+Luis+Obispo
# Retrieved 1385 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=California+State+University+San+Bernardino
# Retrieved 1726 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=City+of+Westminster+College
# Retrieved 1527 characters {"type":"FeatureColl
# Pausing for a bit...
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Columbia+University
# Retrieved 1538 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Cranfield+University
# Retrieved 1482 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Czech+Technical+University+in+Prague
# Retrieved 1505 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=De+Anza+College
# Retrieved 1520 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Dnipropetrovsk+National+University
# Retrieved 1620 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=University+of+Texas+at+Austin
# Retrieved 1492 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Duke+University
# Retrieved 1457 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=EM+Lyon
# Retrieved 1286 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Ecole+centrale+de+PARIS
# Retrieved 1714 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Elon+University
# Retrieved 1367 characters {"type":"FeatureColl
# Pausing for a bit...
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Erhvervsakademi+Sydvest
# Retrieved 1534 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Escuela+Superior+Politecnica+del+Litoral
# Retrieved 1492 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Fachhochschule+Dusseldorf
# Retrieved 1382 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Fachhochschule+FH+Salzburg
# Retrieved 1432 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Faculty+of+Technical+Sciences+Novi+Sad+Serbia
# Retrieved 1775 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Farmingdale+State+University
# Retrieved 1392 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Florida+Atlantic+University
# Retrieved 1587 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Franklin+Pierce+College
# Retrieved 1453 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Gauhati+University
# Retrieved 1500 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=George+Mason+University
# Retrieved 1538 characters {"type":"FeatureColl
# Pausing for a bit...
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Georgetown+University+Law+Center
# Retrieved 1551 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Georgia+State+University
# Retrieved 1585 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Groep+T+University
# Retrieved 1502 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Hanoi+University+of+Science+and+Technology
# Retrieved 1505 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Hebrew+University
# Retrieved 1504 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=IIIT+Hyderabad
# Retrieved 1560 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=IIT+KANPUR
# Retrieved 1360 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=IUAV+Venezia
# Retrieved 1454 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Illinois+Institute+of+Technology
# Retrieved 1585 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Illinois+State+University+Joliet+Junior+College
# Retrieved 1511 characters {"type":"FeatureColl
# Pausing for a bit...
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Indian+Institute+of+Technology
# Retrieved 1652 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Indian+School+of+Mines+Dhanbad
# Retrieved 1391 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Indiana+University
# Retrieved 1618 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Indiana+University+at+Bloomington
# Retrieved 1232 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Institut+Superieur+de+technologies
# Retrieved 1506 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Institute+of+Business+and+Modern+Technologies
# Retrieved 107 characters {"type":"FeatureColl
# ==== Object not found ====
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Instituto+Tecnologico+de+Santo+Domingo
# Retrieved 1602 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=International+Institute+of+Information+Technology+Hyderabad
# Retrieved 1816 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Irkutsk+State+University
# Retrieved 1142 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=JADAVPUR+UNIVERSITY
# Retrieved 1452 characters {"type":"FeatureColl
# Pausing for a bit...
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Jawaharlal+Nehru+Technological+University
# Retrieved 1552 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Jawaharlal+Nehru+University
# Retrieved 1618 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Jordan+University+of+Science+and+Technology
# Retrieved 1479 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=K-State
# Retrieved 1441 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Kalamazoo+College
# Retrieved 1458 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Kaunas+Technology+University
# Retrieved 1538 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Kaunas+university+of+technology
# Retrieved 1551 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Kazan+Federal+University
# Retrieved 1575 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Kent+State+University
# Retrieved 1497 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Kharkiv+State+Academy+of+Municipal+Economy+Ukraine
# Retrieved 231 characters {"type":"FeatureColl
# ==== Object not found ====
# Pausing for a bit...
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=King+Mongkuts+University+of+Technology+Thonburi
# Retrieved 1876 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Kokshetau+Institute+of+Economics+and+Management
# Retrieved 1308 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Kyiv+Polytechnic+Institute
# Retrieved 1767 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Kyiv+Polytechnical+Institute
# Retrieved 1282 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Kyiv+Unisersity+of+Oriental+Language
# Retrieved 1376 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Laurentian+University
# Retrieved 1494 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Lisandro+Alvarado
# Retrieved 1511 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Lodz+University+of+Technology
# Retrieved 1552 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Lviv+University
# Retrieved 1031 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Michigan+State+University
# Retrieved 1548 characters {"type":"FeatureColl
# Pausing for a bit...
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Madras+university
# Retrieved 1513 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Marietta+College
# Retrieved 1503 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Masdar+Institute
# Retrieved 1425 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Matematicki+fakultet+Beograd
# Retrieved 1456 characters {"type":"FeatureColl
#
# Found in database Michigan State University
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Middle+East+Technical+University
# Retrieved 1501 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Missouri+University+of+Science+and+Technology
# Retrieved 1720 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Monash+University
# Retrieved 1623 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Monash+University+Churchill+Australia
# Retrieved 1585 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Monterrey+Institute+of+Technology+and+Higher+Education
# Retrieved 1236 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Moscow+Engineering-Physics+Institute
# Retrieved 1355 characters {"type":"FeatureColl
# Pausing for a bit...
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Moscow+Institute+of+Physics+%26+Technology
# Retrieved 1593 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Moscow+State+University
# Retrieved 1351 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=NIT+ROURKELA
# Retrieved 1307 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=NYU
# Retrieved 1287 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Nagpur+University
# Retrieved 1663 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Nanyang+Technological+University
# Retrieved 1512 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=National+Institute+of+Technology+Jalandhar
# Retrieved 1675 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=National+Taiwan+University
# Retrieved 1545 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=National+University+of+Engineering
# Retrieved 1470 characters {"type":"FeatureColl
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=North+Central+College
# Retrieved 1515 characters {"type":"FeatureColl
# Pausing for a bit...
#
# Retrieving https://py4e-data.dr-chuck.net/opengeo?q=Northeastern+University
# Retrieved 1545 characters {"type":"FeatureColl
# Retrieved 100 locations, restart to retrieve more
# Number of features for which the location could not be found: 2
# Run geodump.py to read the data from the database so you can vizualize it on a map.
