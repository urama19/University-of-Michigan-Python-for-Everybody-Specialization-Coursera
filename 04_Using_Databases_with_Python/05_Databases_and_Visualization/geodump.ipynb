# %%
import sqlite3
import json
import codecs

conn = sqlite3.connect('opengeo.sqlite')
cur = conn.cursor()

cur.execute('SELECT * FROM Locations')
fhand = codecs.open('where.js', 'w', "utf-8")
fhand.write("myData = [\n")
count = 0
for row in cur :
    data = str(row[1].decode())
    try: js = json.loads(str(data))
    except: continue

    if len(js['features']) == 0: continue

    try:
        lat = js['features'][0]['geometry']['coordinates'][1]
        lng = js['features'][0]['geometry']['coordinates'][0]
        where = js['features'][0]['properties']['display_name']
        where = where.replace("'", "")
    except:
        print('Unexpected format')
        print(js)

    try :
        print(where, lat, lng)

        count = count + 1
        if count > 1 : fhand.write(",\n")
        output = "["+str(lat)+","+str(lng)+", '"+where+"']"
        fhand.write(output)
    except:
        continue

fhand.write("\n];\n")
cur.close()
fhand.close()
print(count, "records written to where.js")
print("Open where.html to view the data in a browser")
# Out:
# AGH University of Science and Technology 50.065703299999996 19.918958667058632
# Academy of Fine Arts in Warsaw 52.2394966 21.015693129786936
# American University in Cairo 30.04281175 31.23658590813949
# Arizona State University 33.4213174 -111.93316305413154
# Athens Information Technology 37.9425172 23.8706149
# BITS Pilani 17.547185 78.572791
# Babcock University 6.88997525 3.7224790878605756
# Banaras Hindu University 25.2662887 82.9927969
# Bangalore University 12.944172049999999 77.5091485894286
# Baylor University 31.55043405 -97.1102905567766
# Beijing Normal University (BNU) 39.959732 116.35973697755406
# Belarusian State University 53.83806745 27.476155257195504
# Belgrade University 44.81842 20.45757
# Beloit College 42.5009819 -89.0157777411969
# Unexpected format
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-90.45997, 35.95422]}, 'properties': {'country_code': 'us', 'country': 'United States', 'county': 'Craighead County', 'datasource': {'sourcename': 'whosonfirst', 'url': 'https://www.whosonfirst.org/docs/licenses/'}, 'state': 'Arkansas', 'city': 'State University', 'state_code': 'AR', 'lon': -90.45997, 'lat': 35.95422, 'result_type': 'city', 'formatted': 'State University, AR, United States of America', 'address_line1': 'State University, AR', 'address_line2': 'United States of America', 'timezone': {'display_name': 'America/Chicago', 'offset_STD': '-06:00', 'offset_STD_seconds': -21600, 'offset_DST': '-05:00', 'offset_DST_seconds': -18000, 'abbreviation_STD': 'CST', 'abbreviation_DST': 'CDT'}, 'plus_code': '867FXG3R+M2', 'rank': {'popularity': 1.2820358257326678, 'confidence': 0.6666666666666667, 'confidence_city_level': 0.6666666666666667, 'match_type': 'full_match'}, 'place_id': '5108c90226709d56c059359886e123fa4140c00208e2031f77686f736f6e66697273743a6c6f63616c6974793a31333237343531323933'}, 'bbox': [-90.47997, 35.93422, -90.43997, 35.97422]}], 'query': {'text': 'Belorussian State University'}}
# Beloit College 35.95422 -90.45997
# Ben Gurion University of the Negev 31.2631254 34.802238544584185
# Boston University 42.3504324 -71.10170122505716
# California Polytechnic State University - San Luis Obispo 35.30059 -120.66004
# California State University, San Bernardino 34.18191745 -117.32174391836504
# City of Westminster College 51.5213399 -0.1748934415893599
# Columbia University 40.80775585 -73.96164946987652
# Cranfield University 52.070132900000004 -0.6287023427161589
# Czech Technical University in Prague 50.1029026 14.3946353
# De Anza College 37.31770065 -122.04455706238198
# Dnipro National University 48.434716800000004 35.03785522939141
# University of Texas at Austin 30.2851494 -97.73393515146053
# Duke University 36.00015569999999 -78.94422972195878
# 7th Arr. 45.732398 4.835571
# Écoquartier LaVallée (en travaux) 48.76418645 2.290431301339286
# Elon University 36.10652745 -79.50282572055133
# Erhvervsakademi Sydvest 55.48841555 8.447026487581917
# ESCUELA SUPERIOR POLITECNICA DEL LITORAL -2.147712 -79.9647289
# Fachhochschule Düsseldorf 51.24839645 6.770322755895527
# Fachhochschule Salzburg 47.72360745 13.086718915696402
# Faculty of Technical Sciences 45.2464728 19.851704147473647
# Farmingdale State University of New York 40.75278 -73.42778
# Florida Atlantic University 26.119403650000002 -80.14169191096471
# Franklin Pierce College 43.2125814 -71.4947929
# Gauhati University 26.153410700000002 91.6657647108439
# George Mason University 38.83133325 -77.30798838879116
# Georgetown University Law Center 38.897836749999996 -77.01292415460526
# Georgia State University 33.7535889 -84.38542086620515
# Campus Groep T 50.87485475 4.70793104833482
# Hanoi University of Science and Technology 21.0055269 105.84359264177206
# Hebrew University - Givat Ram Campus 31.77293975 35.197994954152726
# Unexpected format
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [78.349956, 17.445489]}, 'properties': {'country_code': 'in', 'country': 'India', 'county': 'Hyderabad', 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'street': 'International Institute of Information Technology, Hyderabad', 'postcode': '500032', 'state': 'Andhra Pradesh', 'city': 'Hyderabad', 'district': 'West Zone', 'suburb': 'Gachibowli', 'state_code': 'AP', 'lon': 78.349956, 'lat': 17.445489, 'result_type': 'amenity', 'formatted': 'International Institute of Information Technology, Hyderabad, Gachibowli, Hyderabad - 500032, AP, India', 'address_line1': 'International Institute of Information Technology, Hyderabad', 'address_line2': 'Gachibowli, Hyderabad - 500032, AP, India', 'timezone': {'display_name': 'Asia/Kolkata', 'offset_STD': '+05:30', 'offset_STD_seconds': 19800, 'offset_DST': '+05:30', 'offset_DST_seconds': 19800, 'abbreviation_STD': 'IST', 'abbreviation_DST': 'IST'}, 'plus_code': '7J9WC8WX+5X', 'plus_code_short': 'C8WX+5X Hyderabad, India', 'rank': {'popularity': 3.390358317257257, 'confidence': 1, 'confidence_city_level': 1, 'match_type': 'full_match'}, 'place_id': '517fc2d9ad65965340594dba2d910b723140f00102f901b871de0100000000c00201e203206f70656e7374726565746d61703a76656e75653a7761792f3331333535333230'}, 'bbox': [78.3442591, 17.4419862, 78.3522336, 17.4488423]}], 'query': {'text': 'IIIT Hyderabad', 'parsed': {'house': 'iiit', 'city': 'hyderabad', 'expected_type': 'amenity'}}}
# Hebrew University - Givat Ram Campus 17.445489 78.349956
# IIT Kanpur 26.5093058 80.24823225761622
# Bar Iuav 45.4378506 12.3226823
# Illinois Institute of Technology 41.83616405 -87.62647227745128
# Illinois State University 40.51799375 -89.00846070697986
# Indian Institute Of Technology 17.422488350000002 78.54044690040888
# School of Mines -15.394991 28.332815
# Indiana University Bloomington 39.1802358 -86.50935262731483
# Unexpected format
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-85.800815, 43.879022]}, 'properties': {'country_code': 'us', 'street': 'Bloomington', 'country': 'United States', 'county': 'Lake County', 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'state': 'Michigan', 'district': 'Yates Township', 'city': 'Yates', 'state_code': 'MI', 'lon': -85.800815, 'lat': 43.879022, 'result_type': 'street', 'formatted': 'Bloomington, Yates, MI, United States of America', 'address_line1': 'Bloomington', 'address_line2': 'Yates, MI, United States of America', 'timezone': {'display_name': 'America/Detroit', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '86MPV5HX+JM', 'rank': {'popularity': 1.2894103750572092, 'confidence': 0, 'match_type': 'full_match'}, 'place_id': '515cc98e8d407355c059753bfbca83f04540c00204e203266f70656e7374726565746d61703a7374726565743a706f6c796c696e653a3231313831393232'}, 'bbox': [-85.801699, 43.878968, -85.799931, 43.879075]}], 'query': {'text': 'Indiana University at Bloomington'}}
# Indiana University Bloomington 43.879022 -85.800815
# Institut Supérieur de Technologies 14.7168914 -17.4556123
# Instituto Tecnológico de Santo Domingo 18.4876505 -69.96210823269232
# International Institute of Information Technology, Hyderabad 17.4454957 78.34854697544472
# Unexpected format
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-90.45997, 35.95422]}, 'properties': {'country_code': 'us', 'country': 'United States', 'county': 'Craighead County', 'datasource': {'sourcename': 'whosonfirst', 'url': 'https://www.whosonfirst.org/docs/licenses/'}, 'state': 'Arkansas', 'city': 'State University', 'state_code': 'AR', 'lon': -90.45997, 'lat': 35.95422, 'result_type': 'city', 'formatted': 'State University, AR, United States of America', 'address_line1': 'State University, AR', 'address_line2': 'United States of America', 'timezone': {'display_name': 'America/Chicago', 'offset_STD': '-06:00', 'offset_STD_seconds': -21600, 'offset_DST': '-05:00', 'offset_DST_seconds': -18000, 'abbreviation_STD': 'CST', 'abbreviation_DST': 'CDT'}, 'plus_code': '867FXG3R+M2', 'rank': {'popularity': 1.2820358257326678, 'confidence': 0.6666666666666667, 'confidence_city_level': 0.6666666666666667, 'match_type': 'full_match'}, 'place_id': '5108c90226709d56c059359886e123fa4140c00208e2031f77686f736f6e66697273743a6c6f63616c6974793a31333237343531323933'}, 'bbox': [-90.47997, 35.93422, -90.43997, 35.97422]}], 'query': {'text': 'Irkutsk State University'}}
# International Institute of Information Technology, Hyderabad 35.95422 -90.45997
# Jadavpur University 22.5611537 88.4131019353334
# Jawaharlal Nehru Technological University (JNTUK) 16.9786772 82.2411916
# Jawaharlal Nehru University 28.540166749999997 77.16456005394733
# Jordan University of Science and Technology 32.49339995 35.989854503370836
# K-State Student Union 39.18825185 -96.58258555991623
# Kalamazoo College 42.29075735 -85.59936465969835
# Kaunas University of Technology 54.898805249999995 23.912663150766285
# Kaunas University of Technology 54.898805249999995 23.912663150766285
# Kazan Federal University 55.79069515 49.12192908363142
# Kent State University 41.144232450000004 -81.33983207322399
# King Mongkut’s University of Technology Thonburi Alumni Association Under Royal Patronage 13.6502685 100.4954045
# Unexpected format
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-75.075191, 40.138138]}, 'properties': {'country_code': 'us', 'street': 'Management Trail', 'country': 'United States', 'county': 'Montgomery County', 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'state': 'Pennsylvania', 'district': 'Lower Moreland Township', 'city': 'Lower Moreland', 'state_code': 'PA', 'lon': -75.075191, 'lat': 40.138138, 'result_type': 'street', 'formatted': 'Management Trail, Lower Moreland, PA, United States of America', 'address_line1': 'Management Trail', 'address_line2': 'Lower Moreland, PA, United States of America', 'timezone': {'display_name': 'America/New_York', 'offset_STD': '-05:00', 'offset_STD_seconds': -18000, 'offset_DST': '-04:00', 'offset_DST_seconds': -14400, 'abbreviation_STD': 'EST', 'abbreviation_DST': 'EDT'}, 'plus_code': '87G64WQF+7W', 'rank': {'popularity': 3.8776498801582133, 'confidence': 0, 'match_type': 'full_match'}, 'place_id': '51077de9edcfc452c059dc2a8881ae114440c00204e203266f70656e7374726565746d61703a7374726565743a706f6c796c696e653a3134323837343239'}, 'bbox': [-75.076837, 40.136918, -75.075076, 40.139667]}], 'query': {'text': 'Kokshetau Institute of Economics and Management'}}
# King Mongkut’s University of Technology Thonburi Alumni Association Under Royal Patronage 40.138138 -75.075191
# National Technical University of Ukraine “Igor Sikorsky Kyiv Polytechnic Institute” 50.4492335 30.45774515127229
# Kyiv Polytechnical Institute 50.44892 30.45891
# Taras Shevchenko National University of Kyiv 50.44209 30.50821
# Laurentian University 46.4666416 -80.9738711
# Lisandro Alvarado 10.4730027 -66.8928687
# University of Technology 18.0164751 -76.743473
# Unexpected format
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [23.320647, 49.362304]}, 'properties': {'country_code': 'ua', 'country': 'Ukraine', 'county': "Drohobyts'kyi", 'datasource': {'sourcename': 'whosonfirst', 'url': 'https://www.whosonfirst.org/docs/licenses/'}, 'state': 'Lviv', 'city': 'Lviv University', 'lon': 23.320647, 'lat': 49.362304, 'result_type': 'city', 'formatted': 'Lviv University, Lviv, Ukraine', 'address_line1': 'Lviv University', 'address_line2': 'Lviv, Ukraine', 'timezone': {'display_name': 'Europe/Kyiv', 'offset_STD': '+02:00', 'offset_STD_seconds': 7200, 'offset_DST': '+03:00', 'offset_DST_seconds': 10800, 'abbreviation_STD': 'EET', 'abbreviation_DST': 'EEST'}, 'plus_code': '8GX5986C+W7', 'rank': {'popularity': 2.9921027222939363, 'confidence': 1, 'confidence_city_level': 1, 'match_type': 'full_match'}, 'place_id': '517e8ffaeb1552374059e19a3bfa5fae4840c00208e2031e77686f736f6e66697273743a6c6f63616c6974793a313031383630303835'}, 'bbox': [23.300647, 49.342304, 23.340647, 49.382304]}], 'query': {'text': 'Lviv University'}}
# University of Technology 49.362304 23.320647
# Michigan State University 42.70237935 -84.48038686520441
# Madras University Library 13.06686 80.28347
# Marietta College 39.416095049999996 -81.4484225136152
# Masdar Institute 24.4348507 54.6167989
# Faculty of Mathematics 44.8000034 20.4848369
# Middle East Technical University 39.875496749999996 32.78553505584672
# Missouri University of Science and Technology 37.952905900000005 -91.77385818768353
# Monash University (Caulfield campus) -37.8774234 145.04496691740303
# Unexpected format
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [145.045082, -37.877574]}, 'properties': {'country_code': 'au', 'country': 'Australia', 'county': 'Glen Eira', 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'street': 'Monash University (Caulfield campus)', 'state': 'Victoria', 'district': 'Caulfield East', 'city': 'Caulfield East', 'state_code': 'VIC', 'lon': 145.045082, 'lat': -37.877574, 'result_type': 'amenity', 'postcode': '3145', 'suburb': 'Caulfield East', 'formatted': 'Monash University (Caulfield campus), Caulfield East VIC 3145, Australia', 'address_line1': 'Monash University (Caulfield campus)', 'address_line2': 'Caulfield East VIC 3145, Australia', 'timezone': {'display_name': 'Australia/Melbourne', 'offset_STD': '+10:00', 'offset_STD_seconds': 36000, 'offset_DST': '+11:00', 'offset_DST_seconds': 39600, 'abbreviation_STD': 'AEST', 'abbreviation_DST': 'AEDT'}, 'plus_code': '4RJ742CW+X2', 'plus_code_short': 'CW+X2 Caulfield East, Glen Eira, Australia', 'rank': {'popularity': 4.525461718448562, 'confidence': 0.567, 'confidence_city_level': 0.567, 'match_type': 'full_match'}, 'place_id': '516d74ce4f7121624059f3e8465854f042c0f00102f901b760a90100000000c00201e203206f70656e7374726565746d61703a76656e75653a7761792f3237383737353539'}, 'bbox': [145.0428063, -37.8786293, 145.047069, -37.8758634]}], 'query': {'text': 'Monash University Churchill Australia', 'parsed': {'house': 'monash university', 'city': 'churchill', 'country': 'australia', 'expected_type': 'amenity'}}}
# Monash University (Caulfield campus) -37.877574 145.045082
# Unexpected format
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'geometry': {'type': 'Point', 'coordinates': [-92.987376, 34.527022]}, 'properties': {'country_code': 'us', 'street': 'Higher Ground', 'country': 'United States', 'county': 'Garland County', 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'state': 'Arkansas', 'state_code': 'AR', 'lon': -92.987376, 'lat': 34.527022, 'result_type': 'street', 'formatted': 'Higher Ground, Garland County, AR, United States of America', 'address_line1': 'Higher Ground', 'address_line2': 'Garland County, AR, United States of America', 'timezone': {'display_name': 'America/Chicago', 'offset_STD': '-06:00', 'offset_STD_seconds': -21600, 'offset_DST': '-05:00', 'offset_DST_seconds': -18000, 'abbreviation_STD': 'CST', 'abbreviation_DST': 'CDT'}, 'plus_code': '8669G2G7+R2', 'rank': {'popularity': 1.3805804878080288, 'confidence': 0, 'match_type': 'full_match'}, 'place_id': '51bd361b2b313f57c059e222f77475434140c00204e203266f70656e7374726565746d61703a7374726565743a706f6c796c696e653a3138323939383432'}, 'bbox': [-92.98878, 34.523034, -92.983325, 34.530579]}], 'query': {'text': 'Monterrey Institute of Technology and Higher Education'}}
# Monash University (Caulfield campus) 34.527022 -92.987376
# Horia Hulubei National Institute of Physics and Nuclear Engineering 44.45628 26.13643
# Moscow Institute of Physics and Technology 55.60460415 38.10651526217077
# Moscow State University 55.70229715 37.53179772747929
# NIT Rourkela 22.2501589 84.90668556980866
# Nyu 38.6272681 140.4365868
# Rashtrasant Tukadoji Maharaj Nagpur University 21.147717450000002 79.03924327117383
# Nanyang Technological University 1.3484104000000001 103.68293320728537
# Dr. B. R. Ambedkar National Institute of Technology, Jalandhar 31.39571075 75.5357675438753
# National Taiwan University 25.01688615 121.53852099555085
# National University of Engineering -12.02037945 -77.04816939032196
# North Central College 41.774365450000005 -88.14274924248255
# Northeastern University 42.33907025 -71.08783833987422
# 99 records written to where.js
# Open where.html to view the data in a browser
